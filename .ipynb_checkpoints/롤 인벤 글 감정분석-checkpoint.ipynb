# %%
##인벤 글 크롤러 만들기
##롤 인벤 -> 챔피언 공략 게시판 -> 글 제목을 가져와서 글 제목을 통한 감정분석
##시즌에 대한 평가와 챔피언에 대한 평가 살펴보기

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
from time import sleep

# %%
driver = webdriver.Chrome('C:/Temp/chromedriver')
driver.get("https://lol.inven.co.kr/dataninfo/champion/manualTool.php")

soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
## 11시즌과 관련된 글만 가져오기 위해 11시즌 선택
season_select = driver.find_element_by_xpath("//*[@id='lolDbManualToolList']/div[2]/table/tbody/tr[1]/th[2]/a")
season_select.click()

season_11 = driver.find_element_by_xpath("//*[@id='selectMode']/ul/li[1]/a")
season_11.click()

# %%
headline_list = []

# %%
while True:
    sleep(1)
    next_button = driver.find_element_by_class_name("nexttext")
    end = driver.find_element_by_xpath("//*[@id='lolDbManualToolList']/div[2]/table/tbody/tr[2]/td")
    if end.text == "검색 결과가 없습니다.":
        break
    else:
        write_num = driver.find_elements_by_xpath("//*[@id='lolDbManualToolList']/div[2]/table/tbody/tr")
        for i in range(2,len(write_num)+1):
            headline = driver.find_element_by_xpath("//*[@id='lolDbManualToolList']/div[2]/table/tbody/tr[" + str(i) + "]/td[3]/a").text
            headline_list.append(headline)
        
        next_button.click()
    
print(headline_list)
# Out:
# ['마스터3개달성 바루스장인의 모든것..', '[top]포식자 나서스 11.11', '미완성) M1 서폿의 챔피언 맛보기 / 라칸편', 'M1 서폿의 챔피언 맛보기 / 노틸러스편', 'M1 서폿의 챔피언 맛보기 / 카르마편', 'M1 서폿의 챔피언 맛보기 / 레오나편', '미완성. 아직 보지마세요) M1 서폿의 챔피언..', '미완성) M1 서폿의 챔피언 맛보기 / 잔나편', '나서스 원툴러의 나서스 공략, 상대법', "210511 AutoRefresh's 자르반", "210511 AutoRefresh's 세나", '유미의 새 패러다임, 원딜유기메타 "척추 키..', '[루나린] 아리 공략 :)', '11.11) 이제는 대세가 된 정복자 마이', '미완성. 아직 보지마세요) M1 서폿의 챔피언..', 'ㅍㅇㅋ', '미완성. 아직 보지마세요) M1 서폿의 챔피언..', 'M1 서폿의 챔피언 맛보기 / 벨코즈편', '정글 워윅 11.11패치 신파자 버프로 떡상 ..', '11.11패치 신파자 버프 정글나서스 떡상각', '7개월간 연구한 짜오장인공략글(미완)', '폭딜 방관미포', '개인저장용 혹은 아트입문자들을 위한', '미완성. 아직 보지마세요) M1 서폿의 챔피언..', 'M1 자발or월식진 (검증완료)', '[D3] 탑 피오라 공략(상대법 위주)', '♣ <시즌11> 과다치유 뼈방패 케일', '시즌 3부터 아무무원챔 다이아 방송 ON', '[정글] 11.11 정글 포지션 사망', '[시즌 11 제라스] 연습만 하면 티어 수직상..', '서폿 세라핀 공략 & 원리 설명', 'M1 룰루 서폿', 'M1 마오카이 서폿 탱/AP 공략', 'M1 원딜 방관 진 자발/월식 템트리 설명해드..', 'M1 ) 고분기의 트붕이 교보재 (feat..', '[D4] 11시즌에도 돌아온 치명타 클레드', '그마 나르원챔 나르공략', '탐켄치 공략 정석', '떳다', '◈《11.11》 타릭과 정글의 속
&템트리 ..', '맞다이 최적화 카운터 바이', '정글 워윅 시즌 11', 'D2) 진 모스트1 11.10패치 기준 공략', '11시즌 리븐공략(개인애정으로 작성)', 'S4) 정신나간 탑 레오나 한번해볼필요가 있..', '미드 원딜 원하는대로 딸수있는 자발리신', '허니아식 소라카', '[D1]90년생 아조씨의 E선마 스카너', '이세카이 트페/슈렐봉풀주 (챔프별 상대법)', '극 쉴드충 여진딜탱바이', '브론즈 꿀챔 트린다미어 공략', 'z', '덤프트럭 말파', '유미56만점이 처음 쓰는 공략 (지적, 질문 ..', '나 불탄다', '아브실골 유저에게 바치는 리신공략', '달라진 치속 일라오이! 폭발적인 딜! (핫픽..', '[G4] 케일 좋아보이는 빌드 하나만 소개', '서폿 제라스 아주 좋소', '무라마나 스카너', 'M1 [ 미드독학 ] 아지르만해서 그마..', '(간략) 시즌 11 브루저 쉔 [高숙련자 용](w..', '5/4 템트리 정리(선혈포식자 카직스..', '썬파', 'D2 ↑ 장인랭킹 1위 <니트> 마이의 정립.', '수호자 공략 시작합니다.', '슈퍼오른', '화공탱 너프 우디르 그래도 막을수 없습니다..', 'tzs', '키아나 A to Z', '나미 많이 사랑해주세요', '장인랭킹1위 "PONY" 시즌11 정글헤카림 11...', 'D3) [11시즌] 꿀챔 찾으시나요?', '아리 아리 아리랑', 'W선마로 사기치는 세트', '초심자를 위한 진 공략. 원딜 입문에..', '[목빨간새]라이즈에 대한 이야기들입니다.', '트페로 다이아찍으면서 보고 느낀것들 적어..', 'D2) 내가 하는 챔프는 공략글이 없더라 든든..', '케이틀린', '녹턴 템트리(크라켄,몰락,도미닉)', '니달리 창 무조건 맞히는 법과 4버프 운영 ..', '정글 자.폭가렌', '서폿)원딜 암살자 뽀삐(+영상)', '그웬 정글은 이속과 스플릿', '[JUSTRELL]', '[D1] 집중공격 신 짜오', '기발그웬', '[프리시즌]진정한 상남자의 챔프', '[손성은] 만년서리로 갈아탔습니다☆', '나무 고추', '전성기 시절 세트 느낌이 난다', '탱궨', '제드장인은 아니지만 쓸 만한 가치가 있는 ..', '전세계 제드1위가 알려주는 제드 꿀팁', '정글 리븐 6.11 연구 및 공사중 입니다', '역병힐러 트위치', '강력한 (탑,미드) 그웬', '난입 탑 소라카', '((시즌11))최신판. 비대칭전력 정글 피들스..', "진심 역겨운 뉴메타 '수호자 화공 탱 샤코'..", '짬짜면 같은 얼건내셔 그웬', '서리불꽃 그웬 ( 공략이라 할건 없지만 템트..', '밤수 미드자크 공략', '[11시즌] 서폿 없어도 크는 완전 솔랭형 이..', '그웬원챔', '북미시즌-시즌 초창기 고인물이 쓴 공략', '1빠', '무지성 킬각 다리우스', '(미드/탑) 집공or칼날비 그브', '시즌11 탑가렌 공략(21.04.16. 업데이트)', '밤의 수확자 탱직스', '내가 제일 많이하는 미스포 ...
